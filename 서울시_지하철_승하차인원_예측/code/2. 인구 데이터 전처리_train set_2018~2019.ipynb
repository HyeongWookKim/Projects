# %% [markdown]
# **<파일 경로>**
# - C:/Users/Brian/Desktop/Data Science/Projects/Playdata/dataset/population/train

# %%
filepath = input()
# Out:
# C:/Users/Brian/Desktop/Data Science/Projects/Playdata/dataset/population/train

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# # 2018~2019년 인구 데이터 결합
# **<참고>**
# - 데이터들을 불러올 때, 다음과 같은 warning이 발생하였다.
#     - DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#     - 이를 해결해주기 위해 ```dtype = {'기준일ID': str}``` 라는 옵션을 걸어주었다.
#         - 여기서는 Columns (1) = '기준일ID'이다.

# %%
# 2018년 인구 데이터
file_1 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201801.csv'.format(filepath), dtype = {'기준일ID': str})
file_2 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201802.csv'.format(filepath), dtype = {'기준일ID': str})
file_3 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201803.csv'.format(filepath), dtype = {'기준일ID': str})
file_4 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201804.csv'.format(filepath), dtype = {'기준일ID': str})
file_5 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201805.csv'.format(filepath), dtype = {'기준일ID': str})
file_6 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201806.csv'.format(filepath), dtype = {'기준일ID': str})
file_7 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201807.csv'.format(filepath), dtype = {'기준일ID': str})
file_8 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201808.csv'.format(filepath), dtype = {'기준일ID': str})
file_9 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201809.csv'.format(filepath), dtype = {'기준일ID': str})
file_10 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201810.csv'.format(filepath), dtype = {'기준일ID': str})
file_11 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201811.csv'.format(filepath), dtype = {'기준일ID': str})
file_12 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201812.csv'.format(filepath), dtype = {'기준일ID': str})

# 2019년 인구 데이터
file_13 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201901.csv'.format(filepath), dtype = {'기준일ID': str})
file_14 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201902.csv'.format(filepath), dtype = {'기준일ID': str})
file_15 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201903.csv'.format(filepath), dtype = {'기준일ID': str})
file_16 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201904.csv'.format(filepath), dtype = {'기준일ID': str})
file_17 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201905.csv'.format(filepath), dtype = {'기준일ID': str})
file_18 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201906.csv'.format(filepath), dtype = {'기준일ID': str})
file_19 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201907.csv'.format(filepath), dtype = {'기준일ID': str})
file_20 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201908.csv'.format(filepath), dtype = {'기준일ID': str})
file_21 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201909.csv'.format(filepath), dtype = {'기준일ID': str})
file_22 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201910.csv'.format(filepath), dtype = {'기준일ID': str})
file_23 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201911.csv'.format(filepath), dtype = {'기준일ID': str})
file_24 = pd.read_csv('{}/LOCAL_PEOPLE_DONG_201912.csv'.format(filepath), dtype = {'기준일ID': str})

# %%
concat_list = [file_1, file_2, file_3, file_4, file_5, file_6, file_7, file_8, file_9, file_10, file_11, file_12,
               file_13, file_14, file_15, file_16, file_17, file_18, file_19, file_20, file_21, file_22, file_23, file_24]

pop_total = pd.concat(concat_list, axis = 0, ignore_index = True)
pop_total.head()
# Out:
#    Unnamed: 0     기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 0           0  20180101      0  11110515  14471.4116       527.7090
# 1           1  20180101      0  11110530  23059.7992       715.9096
# 2           2  20180101      0  11110540   4928.6410        83.2518
# 3           3  20180101      0  11110550  14060.9810       268.6168
# 4           4  20180101      0  11110560  20322.3298       515.5184
#
#    남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  ...  \
# 0         336.2573         381.2662         551.7157         567.6465  ...
# 1         318.1821         461.8743        1074.8617         959.5067  ...
# 2          63.7905          86.3778         255.9185         253.8867  ...
# 3         208.2819         331.6045         483.0823         421.1730  ...
# 4         372.8914         552.9593         594.7631         559.0723  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# ...

# %%
pop_total.drop(['Unnamed: 0'], axis = 1, inplace = True)
pop_total.tail()
# Out:
#             기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 7306363  20191231     23  11740610  47108.0384      1530.5533
# 7306364  20191231     23  11740685  56004.5812      1777.7481
# 7306365  20191231     23  11740640  26471.4234      1150.2747
# 7306366  20191231     23  11740650  27986.5462      1070.9042
# 7306367  20191231     23  11740700  32974.4339      1364.7863
#
#          남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 7306363         684.2480        1261.2936        1346.8427        1772.9466
# 7306364         859.6586        1252.0765        1500.0176        1999.8669
# 7306365         594.0026         731.9921         543.0908         682.9012
# 7306366         371.4830         566.1300         747.7386        1173.3330
# 7306367         688.4728         816.0758         762.3534         957.2146
#
#          남자30세부터34세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# 7306363        1919.2425  ...        1778.4421        1836.2225
# ...

# %% [markdown]
# # '기준일ID' 변수 수정
# - 데이터를 불러와서 DtypeWarning이 발생한 원인에 대해 확인해보니, 인구 데이터의 "날짜(date)" 변수에 ' 20181130**"** ' 이라는 값이 존재했기 때문임을 확인할 수 있었다.
# - 따라서 해당 값을 수정해주겠다.
#     - 20181130**"** >> 20181130
# - 그 다음 '기준일ID' 변수만 타입을 datetime으로 변경해주겠다.

# %%
# 아래의 코드를 통해 index 번호가 '3388608'인 데이터가 문제임을 확인할 수 있다.
pop_total[pop_total['기준일ID'].str.len() != 8]
# Out:
#              기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 3388608  20181130"      0  11530780  47625.4881      2654.1111
#
#          남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 3388608         1046.095        1016.5548        1102.0546        1311.1105
#
#          남자30세부터34세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# 3388608        1520.9183  ...         1713.402        1731.1882
#
#          여자35세부터39세생활인구수  여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  \
# 3388608        2082.0321        2053.8532        1802.4338        1537.2766
#
#          여자55세부터59세생활인구수  여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 3388608        1868.3088        1628.7575         1354.761     3380.1261
#
# [1 rows x 32 columns]

# %%
# 해당 index 번호의 값을 수정
pop_total['기준일ID'][3388608] = '20181130'
# Out:
# <ipython-input-7-e54a2b417de9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop_total['기준일ID'][3388608] = '20181130'

# %%
pop_total['기준일ID'] = pd.to_datetime(pop_total['기준일ID'], format = '%Y-%m-%d')

# %% [markdown]
# # 변수명 변경
# - 한글로 되어 있는 변수명을 모두 영어로 변경해주겠다.

# %%
new_colnames = {'기준일ID':'date', '시간대구분':'hour', '행정동코드':'dong_code', '총생활인구수':'total', 
                '남자0세부터9세생활인구수':'m_0_9', '남자10세부터14세생활인구수':'m_10_14', '남자15세부터19세생활인구수':'m_15_19',
                '남자20세부터24세생활인구수':'m_20_24', '남자25세부터29세생활인구수':'m_25_29', '남자30세부터34세생활인구수':'m_30_34',
                '남자35세부터39세생활인구수':'m_35_39', '남자40세부터44세생활인구수':'m_40_44', '남자45세부터49세생활인구수':'m_45_49',
                '남자50세부터54세생활인구수':'m_50_54', '남자55세부터59세생활인구수':'m_55_59', '남자60세부터64세생활인구수':'m_60_64',
                '남자65세부터69세생활인구수':'m_65_69', '남자70세이상생활인구수':'m_over_70', '여자0세부터9세생활인구수':'f_0_9',
                '여자10세부터14세생활인구수':'f_10_14', '여자15세부터19세생활인구수':'f_15_19', '여자20세부터24세생활인구수':'f_20_24',
                '여자25세부터29세생활인구수':'f_25_29', '여자30세부터34세생활인구수':'f_30_34', '여자35세부터39세생활인구수':'f_35_39',
                '여자40세부터44세생활인구수':'f_40_44', '여자45세부터49세생활인구수':'f_45_49', '여자50세부터54세생활인구수':'f_50_54',
                '여자55세부터59세생활인구수':'f_55_59', '여자60세부터64세생활인구수':'f_60_64', '여자65세부터69세생활인구수':'f_65_69',
                '여자70세이상생활인구수':'f_over_70'}

pop_total.rename(columns = new_colnames, inplace = True)
pop_total.head()
# Out:
#         date  hour  dong_code       total     m_0_9   m_10_14   m_15_19  \
# 0 2018-01-01     0   11110515  14471.4116  527.7090  336.2573  381.2662
# 1 2018-01-01     0   11110530  23059.7992  715.9096  318.1821  461.8743
# 2 2018-01-01     0   11110540   4928.6410   83.2518   63.7905   86.3778
# 3 2018-01-01     0   11110550  14060.9810  268.6168  208.2819  331.6045
# 4 2018-01-01     0   11110560  20322.3298  515.5184  372.8914  552.9593
#
#      m_20_24   m_25_29   m_30_34  ...    f_25_29   f_30_34    f_35_39  \
# 0   551.7157  567.6465  486.6423  ...   389.1351  473.6825   635.6879
# 1  1074.8617  959.5067  922.5332  ...  1055.1869  975.7669  1025.8741
# 2   255.9185  253.8867  188.0076  ...   172.6411  142.7509   191.2020
# 3   483.0823  421.1730  331.6272  ...   384.2033  413.4419   545.6471
# 4   594.7631  559.0723  472.6954  ...   513.4737  568.1072   711.6436
#
#     f_40_44   f_45_49   f_50_54   f_55_59   f_60_64   f_65_69  f_over_70
# ...

# %% [markdown]
# # 연령대별 그룹 범주화
# - 남/여 구분 없이 연령대 별로 합쳐주겠다.
# - 다음과 같이 총 7개의 그룹으로 범주화한 연령대 변수를 생성하겠다.
#     - pop_below_20
#         - 20세 미만
#     - pop_20
#         - 20대
#     - pop_30
#         - 30대
#     - pop_40
#         - 40대
#     - pop_50
#         - 50대
#     - pop_60
#         - 60대
#     - pop_over_70
#         - 70세 이상

# %%
# 총 7개의 그룹으로 범주화한 연령대 변수 생성
pop_total['pop_below_20'] = pop_total['m_0_9'] + pop_total['m_10_14'] + pop_total['m_15_19'] + pop_total['f_0_9'] + pop_total['f_10_14'] + pop_total['f_15_19']
pop_total['pop_20'] = pop_total['m_20_24'] + pop_total['m_25_29'] + pop_total['f_20_24'] + pop_total['f_25_29']
pop_total['pop_30'] = pop_total['m_30_34'] + pop_total['m_35_39'] + pop_total['f_30_34'] + pop_total['f_35_39']
pop_total['pop_40'] = pop_total['m_40_44'] + pop_total['m_45_49'] + pop_total['f_40_44'] + pop_total['f_45_49']
pop_total['pop_50'] = pop_total['m_50_54'] + pop_total['m_55_59'] + pop_total['f_50_54'] + pop_total['f_55_59']
pop_total['pop_60'] = pop_total['m_60_64'] + pop_total['m_65_69'] + pop_total['f_60_64'] + pop_total['f_65_69']
pop_total['pop_over_70'] = pop_total['m_over_70'] + pop_total['f_over_70']

# %% [markdown]
# # 필요한 변수들만 추출

# %%
pop_total = pop_total[['date', 'hour', 'dong_code', 'total', 'pop_below_20', 'pop_20', 
                       'pop_30', 'pop_40', 'pop_50', 'pop_60', 'pop_over_70']]
pop_total.head()
# Out:
#         date  hour  dong_code       total  pop_below_20     pop_20     pop_30  \
# 0 2018-01-01     0   11110515  14471.4116     2240.2873  1901.9084  2160.7656
# 1 2018-01-01     0   11110530  23059.7992     2823.3040  3855.7544  4059.9409
# 2 2018-01-01     0   11110540   4928.6410      522.2231   825.1988   692.4254
# 3 2018-01-01     0   11110550  14060.9810     1774.7914  1720.8890  1733.4553
# 4 2018-01-01     0   11110560  20322.3298     2807.5818  2200.1501  2287.0940
#
#       pop_40     pop_50     pop_60  pop_over_70
# 0  2557.8714  2013.3887  1389.6512    2207.5381
# 1  3975.0511  3048.1681  2131.8776    3165.6997
# 2   843.7170   711.8668   570.2299     762.9801
# 3  2197.9273  2334.8394  1845.8798    2453.1990
# 4  3056.2584  3594.8618  2749.7658    3626.6169

# %% [markdown]
# # 행정동코드 변환
# - 인구 데이터의 "행정동코드" 변수가 한글이 아닌 숫자로 적혀있다.
# - 때문에 행정동코드와 행정동을 하나하나 매칭시켜서 변경해주도록 하겠다.
#
# **<참고>**
# - **'11620685':'관악구 신사동'**은 딕셔너리에서 제외시켰다.
#     - 지하철 역 주소 데이터를 보면, '신사동'은 '강남구'에만 존재하기 때문이다.

# %%
dic = {'11110515':'종로구 청운효자동', '11110530':'종로구 사직동', '11110540':'종로구 삼청동', '11110550':'종로구 부암동', 
       '11110560':'종로구 평창동', '11110570':'종로구 무악동', '11110580':'종로구 교남동', '11110600':'종로구 가회동', 
       '11110615':'종로구 종로1.2.3.4가동', '11110630':'종로구 종로5.6가동', '11110640':'종로구 이화동', '11110650':'종로구 혜화동', 
       '11110670':'종로구 창신제1동', '11110680':'종로구 창신제2동', '11110690':'종로구 창신제3동', '11110700':'종로구 숭인제1동', 
       '11110710':'종로구 숭인제2동', 
       
       '11140520':'중구 소공동', '11140540':'중구 회현동', '11140550':'중구 명동', '11140570':'중구 필동', '11140580':'중구 장충동', 
       '11140590':'중구 광희동', '11140605':'중구 을지로동', '11140615':'중구 신당동', '11140625':'중구 다산동', '11140635':'중구 약수동', 
       '11140645':'중구 청구동', '11140650':'중구 신당제5동', '11140665':'중구 동화동', '11140670':'중구 황학동', '11140680':'중구 중림동', 
       
       '11170510':'용산구 후암동', '11170520':'용산구 용산2가동', '11170530':'용산구 남영동', '11170555':'용산구 청파동', 
       '11170560':'용산구 원효로제1동', '11170570':'용산구 원효로제2동', '11170580':'용산구 효창동', '11170590':'용산구 용문동', 
       '11170625':'용산구 한강로동', '11170630':'용산구 이촌제1동', '11170640':'용산구 이촌제2동', '11170650':'용산구 이태원제1동', 
       '11170660':'용산구 이태원제2동', '11170685':'용산구 한남동', '11170690':'용산구 서빙고동', '11170700':'용산구 보광동',
       
       '11200520':'성동구 왕십리제2동', '11200535':'성동구 왕십리도선동', '11200540':'성동구 마장동', '11200550':'성동구 사근동',
       '11740690':'강동구 둔촌제1동', '11740700':'강동구 둔촌제2동'}

# %%
dic_df = pd.DataFrame.from_dict(dic, orient = 'index')
dic_df = dic_df.reset_index()
dic_df.rename(columns = {'index': 'dong_code', 0: 'dong'}, inplace = True)
dic_df
# Out:
#     dong_code       dong
# 0    11110515  종로구 청운효자동
# 1    11110530    종로구 사직동
# 2    11110540    종로구 삼청동
# 3    11110550    종로구 부암동
# 4    11110560    종로구 평창동
# ..        ...        ...
# 418  11740650  강동구 성내제2동
# 419  11740660  강동구 성내제3동
# 420  11740685     강동구 길동
# 421  11740690  강동구 둔촌제1동
# 422  11740700  강동구 둔촌제2동
#
# [423 rows x 2 columns]

# %% [markdown]
# - dong 변수를 "종로구_청운효자동" 이런 식으로 변경해주겠다.

# %%
result = []
for i in range(len(dic_df)):
    dong_split = dic_df['dong'][i].split()
    result.append('_'.join(dong_split))
    
result
# Out:
# ['종로구_청운효자동',
#  '종로구_사직동',
#  '종로구_삼청동',
#  '종로구_부암동',
#  '종로구_평창동',
#  '종로구_무악동',
#  '종로구_교남동',
#  '종로구_가회동',
#  '종로구_종로1.2.3.4가동',
#  '종로구_종로5.6가동',
#  '종로구_이화동',
#  '종로구_혜화동',
#  '종로구_창신제1동',
#  '종로구_창신제2동',
#  '종로구_창신제3동',
#  '종로구_숭인제1동',
#  '종로구_숭인제2동',
#  '중구_소공동',
#  '중구_회현동',
#  '중구_명동',
#  '중구_필동',
#  '중구_장충동',
#  '중구_광희동',
#  '중구_을지로동',
#  '중구_신당동',
#  '중구_다산동',
#  '중구_약수동',
#  '중구_청구동',
#  '중구_신당제5동',
#  '중구_동화동',
#  '중구_황학동',
#  '중구_중림동',
#  '용산구_후암동',
#  '용산구_용산2가동',
#  '용산구_남영동',
#  '용산구_청파동',
#  '용산구_원효로제1동',
#  '용산구_원효로제2동',
#  '용산구_효창동',
#  '용산구_용문동',
#  '용산구_한강로동',
#  '용산구_이촌제1동',
#  '용산구_이촌제2동',
#  '용산구_이태원제1동',
#  '용산구_이태원제2동',
#  '용산구_한남동',
#  '용산구_서빙고동',
#  '용산구_보광동',
#  '성동구_왕십리제2동',
#  '성동구_왕십리도선동',
#  '성동구_마장동',
#  '성동구_사근동',
#  '성동구_행당제1동',
#  '성동구_행당제2동',
#  '성동구_응봉동',
#  '성동구_금호1가동',
#  '성동구_금호2.3가동',
#  '성동구_금호4가동',
#  '성동구_옥수동',
#  '성동구_성수1가제1동',
#  '성동구_성수1가제2동',
#  '성동구_성수2가제1동',
#  '성동구_성수2가제3동',
#  '성동구_송정동',
#  '성동구_용답동',
#  '광진구_화양동',
# ...

# %%
dic_df['dong'] = result
dic_df
# Out:
#     dong_code       dong
# 0    11110515  종로구_청운효자동
# 1    11110530    종로구_사직동
# 2    11110540    종로구_삼청동
# 3    11110550    종로구_부암동
# 4    11110560    종로구_평창동
# ..        ...        ...
# 418  11740650  강동구_성내제2동
# 419  11740660  강동구_성내제3동
# 420  11740685     강동구_길동
# 421  11740690  강동구_둔촌제1동
# 422  11740700  강동구_둔촌제2동
#
# [423 rows x 2 columns]

# %% [markdown]
# - 인구 데이터 셋(pop_total)과 수정된 행정동코드 데이터 셋(dic_df)의 'dong_code' 변수 타입이 서로 다르다.
# - 때문에 dic_df 데이터 셋의 'dong_code' 변수를 int형으로 변경해주겠다.

# %%
pop_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7306368 entries, 0 to 7306367
# Data columns (total 11 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          datetime64[ns]
#  1   hour          int64
#  2   dong_code     int64
#  3   total         float64
#  4   pop_below_20  float64
#  5   pop_20        float64
#  6   pop_30        float64
#  7   pop_40        float64
#  8   pop_50        float64
#  9   pop_60        float64
#  10  pop_over_70   float64
# dtypes: datetime64[ns](1), float64(8), int64(2)
# memory usage: 613.2 MB

# %%
dic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dong_code  423 non-null    object
#  1   dong       423 non-null    object
# dtypes: object(2)
# memory usage: 6.7+ KB

# %%
dic_df['dong_code'] = pd.to_numeric(dic_df['dong_code'])
dic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dong_code  423 non-null    int64
#  1   dong       423 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 6.7+ KB

# %% [markdown]
# - pop_total 데이터 셋에는 'dong_code'가 424개가 존재하는데, dic_df 데이터 셋에는 'dong_code'가 423개 존재한다.
#     - 최종 inner join한 데이터 셋을 통해, 1개 차이로 인해 len이 불일치함을 확인하였다.
# - 따라서 이 부분을 해결해주고 inner join을 수행해주도록 하겠다.
#     - 해결 방안은 직접 비교해서 dic_df 데이터 셋에 미존재하는 **"11710647(00)"** 행정동을 직접 찾아서 넣어주어야 한다.
#     - 구글링을 해 본 결과, **"11710647(00)"**에 해당하는 행정동은 **"위례동"**임을 확인했다.
#     - 그래서 dic(행정동코드 변환 딕셔너리)에 **```'11710647':'위례동'```** 코드를 넣어주었다.
#
# **<참고>**
# - 위 사항들을 확인해보기 위한 코드는 모두 주석 처리 해두었다.

# %%
# pop_total_final = pd.merge(pop_total, dic_df, how = 'inner', on = 'dong_code')
# pop_total_final

# %%
# df1 = pd.DataFrame(set(pop_total['dong_code']))
# df2 = pd.DataFrame(set(dic_df['dong_code']))

# df1.rename(columns = {0:'dong_code'}, inplace = True)
# df2.rename(columns = {0:'dong_code'}, inplace = True)

# check1 = df1.sort_values(by = 'dong_code')
# check2 = df2.sort_values(by = 'dong_code')

# %%
# # c_total 데이터 셋을 50개의 row 씩 잘라서 눈으로 확인
# # 그 결과, dic_df 데이터 셋에 "11710647" 행정동코드가 미존재함을 확인!!
# c_total = pd.concat([check1, check2], axis = 1)

# %%
# pop_total[pop_total['dong_code'] == 11710647]

# %% [markdown]
# - 이제 pop_total 데이터 셋과 dic_df 데이터 셋을 'dong_code' 변수를 조인키로 사용하여 inner join 해주겠다.

# %%
pop_total_final = pd.merge(pop_total, dic_df, how = 'inner', on = 'dong_code')
pop_total_final
# Out:
#               date  hour  dong_code       total  pop_below_20     pop_20  \
# 0       2018-01-01     0   11110515  14471.4116     2240.2873  1901.9084
# 1       2018-01-01     1   11110515  14476.3838     2192.6338  1839.7302
# 2       2018-01-01     2   11110515  14624.7353     2179.0636  1883.6808
# 3       2018-01-01     3   11110515  14667.7190     2187.9826  1884.9999
# 4       2018-01-01     4   11110515  14724.5581     2203.3030  1894.6867
# ...            ...   ...        ...         ...           ...        ...
# 7289131 2019-12-31    19   11740700  28966.0305     4402.7464  2984.5773
# 7289132 2019-12-31    20   11740700  29495.9850     4460.1392  3123.6626
# 7289133 2019-12-31    21   11740700  30131.0225     4616.2185  3210.7351
# 7289134 2019-12-31    22   11740700  31575.9329     5043.9562  3474.2488
# 7289135 2019-12-31    23   11740700  32974.4339     5135.1512  3596.6190
#
#             pop_30     pop_40     pop_50     pop_60  pop_over_70       dong
# ...

# %%
pop_total_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7289136 entries, 0 to 7289135
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          datetime64[ns]
#  1   hour          int64
#  2   dong_code     int64
#  3   total         float64
#  4   pop_below_20  float64
#  5   pop_20        float64
#  6   pop_30        float64
#  7   pop_40        float64
#  8   pop_50        float64
#  9   pop_60        float64
#  10  pop_over_70   float64
#  11  dong          object
# dtypes: datetime64[ns](1), float64(8), int64(2), object(1)
# memory usage: 723.0+ MB

# %% [markdown]
# # 인구수 관련 변수들 데이터 타입 변경
# - 소수점으로 되어 있는 인구수 관련 변수들을 모두 '올림' 처리하여 정수로 만들어주겠다.

# %%
var_list = ['total', 'pop_below_20', 'pop_20', 'pop_30', 'pop_40', 'pop_50', 'pop_60', 'pop_over_70']
pop_total_final[var_list] = np.ceil(pop_total_final[var_list])

# %%
pop_total_final.head()
# Out:
#         date  hour  dong_code    total  pop_below_20  pop_20  pop_30  pop_40  \
# 0 2018-01-01     0   11110515  14472.0        2241.0  1902.0  2161.0  2558.0
# 1 2018-01-01     1   11110515  14477.0        2193.0  1840.0  2157.0  2609.0
# 2 2018-01-01     2   11110515  14625.0        2180.0  1884.0  2232.0  2615.0
# 3 2018-01-01     3   11110515  14668.0        2188.0  1885.0  2197.0  2635.0
# 4 2018-01-01     4   11110515  14725.0        2204.0  1895.0  2207.0  2646.0
#
#    pop_50  pop_60  pop_over_70       dong
# 0  2014.0  1390.0       2208.0  종로구_청운효자동
# 1  2056.0  1400.0       2225.0  종로구_청운효자동
# 2  2099.0  1387.0       2231.0  종로구_청운효자동
# 3  2101.0  1400.0       2263.0  종로구_청운효자동
# 4  2123.0  1396.0       2257.0  종로구_청운효자동

# %% [markdown]
# # 조인키 생성
# - 지하철 데이터 셋을 기준으로 인구 데이터 셋과 기상 데이터 셋을 결합시켜 줄 것이므로, 이를 위한 조인키가 필요하다.
# - 인구 데이터의 'dong' 변수의 경우, "종로구_청운효자동" 이런 식으로 자치구와 행정동이 같이 입력되어 있다.
# - 따라서 다음과 같이 조인키를 생성해주겠다.
#     1. 앞서 했던 방법대로 먼저 문자열을 결합해준다.
#         - ex) "2018-01-01_종로구_청운효자동"
#     2. 만들어진 조인키 변수에서 자치구에 해당 되는 부분은 제거해준다.
#         - ex) "2018-01-01_청운효자동"

# %%
# datetime to string
pop_total_final['date'] = pop_total_final['date'].astype(str)

# 문자열 결합
pop_total_final['pop_join_key'] = pop_total_final['date'] + '_' + pop_total_final['dong']
# '_'를 기준으로 문자열을 잘라서 리스트에 담기
pop_join_key_list = pop_total_final['pop_join_key'].str.split('_').to_list()

# %%
# '자치구' 부분을 제외해 준 뒤에 문자열 재결합
result = []
for i in tqdm(pop_join_key_list):
    result.append('_'.join([i[0], i[2]]))

# 지하철 데이터와 결합할 때 사용할 조인키
pop_total_final['pop_join_key'] = result
pop_total_final['pop_join_key']
# Out:
# ...
# 0          2018-01-01_청운효자동
# 1          2018-01-01_청운효자동
# 2          2018-01-01_청운효자동
# 3          2018-01-01_청운효자동
# 4          2018-01-01_청운효자동
#                  ...
# 7289131    2019-12-31_둔촌제2동
# 7289132    2019-12-31_둔촌제2동
# 7289133    2019-12-31_둔촌제2동
# 7289134    2019-12-31_둔촌제2동
# 7289135    2019-12-31_둔촌제2동
# Name: pop_join_key, Length: 7289136, dtype: object

# %% [markdown]
# # 불필요한 변수들 제거
# - dong_code, dong 변수는 분석에 사용하지 않을 것이므로 제거해주겠다.

# %%
pop_total_final.columns
# Out:
# Index(['date', 'hour', 'dong_code', 'total', 'pop_below_20', 'pop_20',
#        'pop_30', 'pop_40', 'pop_50', 'pop_60', 'pop_over_70', 'dong',
#        'pop_join_key'],
#       dtype='object')

# %%
pop_total_final.drop(['dong_code', 'dong'], axis = 1, inplace = True)

# %%
pop_total_final
# Out:
#                date  hour    total  pop_below_20  pop_20  pop_30  pop_40  \
# 0        2018-01-01     0  14472.0        2241.0  1902.0  2161.0  2558.0
# 1        2018-01-01     1  14477.0        2193.0  1840.0  2157.0  2609.0
# 2        2018-01-01     2  14625.0        2180.0  1884.0  2232.0  2615.0
# 3        2018-01-01     3  14668.0        2188.0  1885.0  2197.0  2635.0
# 4        2018-01-01     4  14725.0        2204.0  1895.0  2207.0  2646.0
# ...             ...   ...      ...           ...     ...     ...     ...
# 7289131  2019-12-31    19  28967.0        4403.0  2985.0  3908.0  4295.0
# 7289132  2019-12-31    20  29496.0        4461.0  3124.0  3979.0  4388.0
# 7289133  2019-12-31    21  30132.0        4617.0  3211.0  4094.0  4453.0
# 7289134  2019-12-31    22  31576.0        5044.0  3475.0  4301.0  4638.0
# 7289135  2019-12-31    23  32975.0        5136.0  3597.0  4413.0  4876.0
#
#          pop_50  pop_60  pop_over_70      pop_join_key
# ...

# %%
pop_total_final.isnull().sum()
# Out:
# date            0
# hour            0
# total           0
# pop_below_20    0
# pop_20          0
# pop_30          0
# pop_40          0
# pop_50          0
# pop_60          0
# pop_over_70     0
# pop_join_key    0
# dtype: int64

# %%
pop_total_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7289136 entries, 0 to 7289135
# Data columns (total 11 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          object
#  1   hour          int64
#  2   total         float64
#  3   pop_below_20  float64
#  4   pop_20        float64
#  5   pop_30        float64
#  6   pop_40        float64
#  7   pop_50        float64
#  8   pop_60        float64
#  9   pop_over_70   float64
#  10  pop_join_key  object
# dtypes: float64(8), int64(1), object(2)
# memory usage: 667.3+ MB

# %% [markdown]
# # 최종 생성된 데이터 셋을 csv 파일로 내보내기

# %%
new_filepath = 'C:/Users/Brian/Desktop/Data Science/Projects/Playdata/dataset/made_by_전처리/train'

# %%
pop_total_final.to_csv('{}/pop_final.csv'.format(new_filepath), index = False)
